# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdulrahmanB-25/Machine_Learning_Competition/blob/main/MetroStationDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  import pandas as pd
  import numpy as np
  import matplotlib.pyplot as plt
  import seaborn as sns

  sns.set_style("whitegrid")

# %%
df = pd.read_csv("metro-stations-in-riyadh-by-metro-line-and-station-type.csv")
df.head()
# Out:
#    رقم العنصر الداخلي رمز محطة المترو          Station name       اسم المحطة  \
# 0                  40             S02  Dr Sulaiman Al Habib  د.سليمان الحبيب
# 1                  49             S03                  KAFD    المركز المالي
# 2                  18             S04             Al Murooj           المروج
# 3                  56             S05   King Fahad District     حي الملك فهد
# 4                  24             S08            Al Wurud 2         الورود 2
#
#   رقم خط المترو Metro line name اسم مسار القطار  رمز نوع المحطة  \
# 0         Line1       Blue line   المسار الأزرق               1
# 1         Line1       Blue line   المسار الأزرق               1
# 2         Line1       Blue line   المسار الأزرق               4
# 3         Line1       Blue line   المسار الأزرق               4
# 4         Line1       Blue line   المسار الأزرق               4
#
#        Station type              نوع المحطة  تسلسل المحطات Comments التعليقات  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   رقم العنصر الداخلي    94 non-null     int64
#  1   رمز محطة المترو       94 non-null     object
#  2   Station name          94 non-null     object
#  3   اسم المحطة            94 non-null     object
#  4   رقم خط المترو         94 non-null     object
#  5   Metro line name       94 non-null     object
#  6   اسم مسار القطار       94 non-null     object
#  7   رمز نوع المحطة        94 non-null     int64
#  8   Station type          94 non-null     object
#  9   نوع المحطة            94 non-null     object
#  10  تسلسل المحطات         94 non-null     int64
#  11  Comments              10 non-null     object
#  12  التعليقات             10 non-null     object
#  13  الإحداثيات الجغرافية  94 non-null     object
#  14  geo_point_2d          94 non-null     object
# ...

# %%
df.isnull().sum()
# Out:
# رقم العنصر الداخلي       0
# رمز محطة المترو          0
# Station name             0
# اسم المحطة               0
# رقم خط المترو            0
# Metro line name          0
# اسم مسار القطار          0
# رمز نوع المحطة           0
# Station type             0
# نوع المحطة               0
# تسلسل المحطات            0
# Comments                84
# التعليقات               84
# الإحداثيات الجغرافية     0
# geo_point_2d             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import re

df = df.loc[:, df.columns.str.contains(r'[a-zA-Z0-9_]')]
print(df.columns)
# Out:
# Index(['Station name', 'Metro line name', 'Station type', 'Comments',
#        'geo_point_2d'],
#       dtype='object')

# %%
df.drop(columns=['Comments'], inplace=True)

# %%
df.head()
# Out:
#            Station name Metro line name      Station type  \
# 0  Dr Sulaiman Al Habib       Blue line          Elevated
# 1                  KAFD       Blue line          Elevated
# 2             Al Murooj       Blue line  Deep Underground
# 3   King Fahad District       Blue line  Deep Underground
# 4            Al Wurud 2       Blue line  Deep Underground
#
#                            geo_point_2d
# 0  24.81155379383345, 46.62654386725997
# 1  24.76800392512061, 46.64364447641301
# 2  24.75474607607529, 46.65422135694412
# 3  24.74491442205136, 46.65932671648558
# 4  24.72172740595173, 46.67112888545265

# %%
import pandas as pd

df_bus = pd.read_csv('bus-stops-in-riyadh-by-bus-route-direction-and-shelter-type.csv')

print(df_bus.columns)
df_bus.head()
# Out:
# Index(['Index', 'Bus station code', 'Bus station name', 'Shelter type code',
#        'Shelter type', 'Bus line code', 'Bus line', 'Direction',
#        'Sequence of the stops', 'Development stage', 'Comments',
#        'Geographical coordinates', 'geo_point_2d'],
#       dtype='object')
#    Index  Bus station code          Bus station name Shelter type code  \
# 0     10             41024    Ali Ibn Abi Talib 17 A                A1
# 1     40             41100  Salahuddin Al Ayubi 16 B                A3
# 2     56             41144                Al Kharj E                 -
# 3    102             42113       Ali Ibn Abi Talib B                 -
# 4    104             42115       Ali Ibn Abi Talib D                 -
#
#   Shelter type Bus line code  Bus line  Direction  Sequence of the stops  \
# 0  BRT station         L31-1      11.0        1.0                   13.0
# 1  BRT station         L31-1      11.0        2.0                    6.0
# ...

# %%
df_bus.describe()
# Out:
#              Index  Bus station code     Bus line    Direction  \
# count  3010.000000       3010.000000  2977.000000  2977.000000
# mean   1505.621595      60802.500332   639.342627     1.209607
# std     869.275416       9023.291282   382.771447     0.407097
# min       1.000000      41001.000000     7.000000     1.000000
# 25%     753.250000      53531.250000   231.000000     1.000000
# 50%    1505.500000      62403.500000   922.000000     1.000000
# 75%    2257.750000      65218.750000   954.000000     1.000000
# max    3132.000000      99531.000000   984.000000     2.000000
#
#        Sequence of the stops
# count            2977.000000
# mean               18.705744
# std                12.958373
# min                 1.000000
# 25%                 9.000000
# 50%                17.000000
# 75%                26.000000
# max                88.000000

# %%
df_bus.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_bus.isnull().sum()
# Out:
# Index                          0
# Bus station code               0
# Bus station name               0
# Shelter type code              0
# Shelter type                  12
# Bus line code                 33
# Bus line                      33
# Direction                     33
# Sequence of the stops         33
# Development stage             33
# Comments                    2977
# Geographical coordinates       0
# geo_point_2d                   0
# dtype: int64

# %%
#null_percentage = (df_bus.isnull().sum() / len(df_bus)) * 100
#display(null_percentage)

# %%
df_bus.drop(columns=['Comments'], inplace=True)

# %%
df_bus.dropna(inplace=True)

# %%
#null_percentage = (df_bus.isnull().sum() / len(df_bus)) * 100
#display(null_percentage)

# %%
df_bus.head()
# Out:
#    Index  Bus station code          Bus station name Shelter type code  \
# 0     10             41024    Ali Ibn Abi Talib 17 A                A1
# 1     40             41100  Salahuddin Al Ayubi 16 B                A3
# 7    345             52326              Al Batha 202                 3
# 8    347             52332              Al Batha 201                 1
# 9    353             52411              Al Kharj 201                 2
#
#                                 Shelter type Bus line code  Bus line  \
# 0                                BRT station         L31-1      11.0
# 1                                BRT station         L31-1      11.0
# 7                    Air conditioned shelter         L19-1       7.0
# 8  Feeder pole with standard site adaptation         L19-1       7.0
# 9                               Open shelter         L39-1     151.0
#
#    Direction  Sequence of the stops Development stage  \
# 0        1.0                   13.0                 4
# ...

# %%
df_bus.shape
# Out:
# (2944, 12)
